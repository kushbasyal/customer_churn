# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
import os
# Adds parent diretory for imports
sys.path.append(os.path.abspath('..'))
# Add scripts folder for imports
sys.path.append('../scripts')

# %%
from scripts.data_cleaner import load_data, clean_data
from scripts.feature_engineering import create_features

# Load raw data from CSV file
df = load_data()
# Extract clean data from data_cleaner after removing duplicates and handling missing values
df_clean = clean_data(df)

df_model = create_features(df_clean)
df_model.head()
# Out:
# Data Load Successfully
#    customer_id  tenure  monthly_charges  total_charges        contract  \
# 0            1      52            54.20        2818.40  Month-to-month
# 1            2      15            35.28         529.20  Month-to-month
# 2            3      72            78.24        5633.28  Month-to-month
# 3            4      61            80.24        4894.64        One year
# 4            5      21            39.38         826.98  Month-to-month
#
#   payment_method internet_service tech_support online_security  support_calls  \
# 0         Credit              DSL           No             Yes              1
# 1          Debit              DSL           No              No              2
# 2          Debit              DSL           No              No              0
# 3           Cash            Fiber          Yes             Yes              0
# 4            UPI            Fiber           No              No              4
#
#   churn
# 0    No
# 1    No
# 2    No
# ...

# %%
num_df = df_model.select_dtypes(include = 'number')
print(num_df)
# Out:
#        customer_id  tenure  monthly_charges  total_charges  support_calls  \
# 0                1      52            54.20        2818.40              1
# 1                2      15            35.28         529.20              2
# 2                3      72            78.24        5633.28              0
# 3                4      61            80.24        4894.64              0
# 4                5      21            39.38         826.98              4
# ...            ...     ...              ...            ...            ...
# 19995        19996      36            69.51        2502.36              0
# 19996        19997      10            59.88         598.80              1
# 19997        19998       6            42.96         257.76              2
# 19998        19999       7           102.85         719.95              2
# 19999        20000      31            44.84        1390.04              1
#
#        avg_monthly_spend  high_risk_customer
# ...

# %%
cat_df = df_model.select_dtypes(include = 'object')
print(cat_df)
# Out:
#              contract payment_method internet_service tech_support  \
# 0      Month-to-month         Credit              DSL           No
# 1      Month-to-month          Debit              DSL           No
# 2      Month-to-month          Debit              DSL           No
# 3            One year           Cash            Fiber          Yes
# 4      Month-to-month            UPI            Fiber           No
# ...               ...            ...              ...          ...
# 19995        Two year           Cash              DSL           No
# 19996  Month-to-month            UPI            Fiber          Yes
# 19997  Month-to-month         Credit            Fiber           No
# 19998  Month-to-month          Debit              DSL          Yes
# 19999        Two year         Credit            Fiber          Yes
#
#       online_security churn
# 0                 Yes    No
# 1                  No    No
# 2                  No    No
# 3                 Yes    No
# ...

# %%
# Correlation heatmap for numerical columns to see their relation
plt.figure(figsize = (10,6))
corr = num_df.corr()
sns.heatmap(corr, annot = True, cmap = 'coolwarm')
plt.title("Numerical features Correlation")
plt.show()

# %%
# Categorical features vs churn distribution
for col in cat_df:
    plt.figure(figsize=(5,3))
    sns.countplot(x=col, hue='churn', data=df)
    plt.title(f'{col} vs Churn')
    plt.show()

# %%
df_model.columns
# Out:
# Index(['customer_id', 'tenure', 'monthly_charges', 'total_charges', 'contract',
#        'payment_method', 'internet_service', 'tech_support', 'online_security',
#        'support_calls', 'churn', 'avg_monthly_spend', 'high_risk_customer'],
#       dtype='object')

# %%
# Based on above analysis ( correlation analysis)
'''
From our correlation matrix analysis, we observed:

avg_monthly_spend is perfectly correlated (1.0) with monthly_charges → redundant, so we drop it.

customer_id is a unique identifier with no predictive power → drop it.

high_risk_customer is a target variable we created manually → keeping it would cause data leakage, so we drop it.

tenure and total_charges have a high correlation (0.77) → we drop total_charges and keep tenure to avoid multicollinearity.

Dropped: customer_id, total_charges, avg_monthly_spend, high_risk_customer
'''
df_model = df_model.drop(columns = ['customer_id', 'total_charges', 'high_risk_customer', 'avg_monthly_spend'])
df_model.head()
# Out:
#    tenure  monthly_charges        contract payment_method internet_service  \
# 0      52            54.20  Month-to-month         Credit              DSL
# 1      15            35.28  Month-to-month          Debit              DSL
# 2      72            78.24  Month-to-month          Debit              DSL
# 3      61            80.24        One year           Cash            Fiber
# 4      21            39.38  Month-to-month            UPI            Fiber
#
#   tech_support online_security  support_calls churn
# 0           No             Yes              1    No
# 1           No              No              2    No
# 2           No              No              0    No
# 3          Yes             Yes              0    No
# 4           No              No              4   Yes

# %%
# Separate dependent and independent data for modeling
X = df_model.iloc[:,:-1]
y = df_model.iloc[:,-1]
print(X)
# Out:
#        tenure  monthly_charges        contract payment_method  \
# 0          52            54.20  Month-to-month         Credit
# 1          15            35.28  Month-to-month          Debit
# 2          72            78.24  Month-to-month          Debit
# 3          61            80.24        One year           Cash
# 4          21            39.38  Month-to-month            UPI
# ...       ...              ...             ...            ...
# 19995      36            69.51        Two year           Cash
# 19996      10            59.88  Month-to-month            UPI
# 19997       6            42.96  Month-to-month         Credit
# 19998       7           102.85  Month-to-month          Debit
# 19999      31            44.84        Two year         Credit
#
#       internet_service tech_support online_security  support_calls
# 0                  DSL           No             Yes              1
# 1                  DSL           No              No              2
# ...

# %%
numerical_data = X.select_dtypes(include ='number')
cat_data = X.select_dtypes(include = 'object')

# %%
print(y)
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4        Yes
#         ...
# 19995    Yes
# 19996     No
# 19997     No
# 19998     No
# 19999    Yes
# Name: churn, Length: 20000, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (16000, 8)
# X_test shape: (4000, 8)
# y_train shape: (16000,)
# y_test shape: (4000,)

# %%
# Define preprocessor to scale numerical data and one-hot encode categorical data

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_data.columns),
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore'), cat_data.columns)
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num', StandardScaler(),
#                                  Index(['tenure', 'monthly_charges', 'support_calls'], dtype='object')),
#                                 ('cat',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  Index(['contract', 'payment_method', 'internet_service', 'tech_support',
#        'online_security'],
#       dtype='object'))])

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 1, 0, 0], shape=(16000,))

# %%
y_test
# Out:
# array([0, 1, 0, ..., 1, 0, 0], shape=(4000,))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %%
models = {
    'Logistic Regression': LogisticRegression(random_state = 0),
    'K-Nearest Neighbours': KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2), 
    'SVM Linear': SVC(kernel = 'linear',random_state = 0),  
    'SVM RBF': SVC(kernel = 'rbf', random_state = 0),
    'Naive Bayes': GaussianNB(),
    'Decision Tree': DecisionTreeClassifier(criterion = 'entropy', random_state = 0),
    'Random Forest': RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0),
    'XGBoost': xgb.XGBClassifier(random_state = 0)
}

# %%
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline

# Dictionary to store results
results = {}
pipelines = {} # store pipeline

for name, model in models.items():
    # Create pipeline
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', model)
    ])
    
    # Train
    pipeline.fit(X_train, y_train)
    pipelines[name] = pipeline # save pipeline
    
    # Predict using predict()
    y_train_pred = pipeline.predict(X_train)
    y_test_pred = pipeline.predict(X_test)
    
    # Calculate accuracy manually
    train_acc = accuracy_score(y_train, y_train_pred)
    test_acc = accuracy_score(y_test, y_test_pred)
    
    # Store
    results[name] = {'Train Accuracy': train_acc, 'Test Accuracy': test_acc}
    print(f"{name}: Train = {train_acc:.4f}, Test = {test_acc:.4f}")
# Out:
# Logistic Regression: Train = 0.7804, Test = 0.7732
# K-Nearest Neighbours: Train = 0.8402, Test = 0.7830
# SVM Linear: Train = 0.7814, Test = 0.7748
# SVM RBF: Train = 0.8267, Test = 0.8143
# Naive Bayes: Train = 0.7819, Test = 0.7823
# Decision Tree: Train = 1.0000, Test = 0.7400
# Random Forest: Train = 0.9766, Test = 0.8157
# XGBoost: Train = 0.8708, Test = 0.8350

# %%
# Extract XGBoost from stored pipelines
from sklearn.model_selection import cross_val_score
print("\n" + "="*50)
print("XGBoost Results")
print("="*50)

xgb_pipeline = pipelines['XGBoost']
y_pred = xgb_pipeline.predict(X_test)

print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay.from_estimator(xgb_pipeline, X_test, y_test)
plt.title("XGBoost")
plt.show()

# Cross-validation score
cv_scores = cross_val_score(xgb_pipeline, X_train, y_train, cv=5)
print(f"\nCross-Validation Scores (5-fold): {cv_scores}")
print(f"Mean CV Score: {cv_scores.mean():.4f}")
print(f"Std CV Score: {cv_scores.std():.4f}")
# Out:
# ...
# XGBoost Results
# ...
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88      2616
#            1       0.84      0.65      0.73      1384
#
#     accuracy                           0.83      4000
#    macro avg       0.84      0.79      0.81      4000
# weighted avg       0.84      0.83      0.83      4000
# Cross-Validation Scores (5-fold): [0.839375  0.83875   0.8484375 0.83125   0.8409375]
# Mean CV Score: 0.8397
# Std CV Score: 0.0055

# %%
def predict_risk(tenure, monthly_charges, contract, payment_method, internet_service, tech_support, online_security, support_calls):
    """
    Predict if a customer is high risk.
    
    Returns: "High Risk" or "Not High Risk" with probability
    """
    # Create dataframe
    customer = pd.DataFrame({
        'tenure': [tenure],
        'monthly_charges': [monthly_charges],
        'contract': [contract],
        'payment_method': [payment_method],
        'internet_service': [internet_service],
        'tech_support': [tech_support],
        'online_security': [online_security],
        'support_calls': [support_calls]
    })
    
    # Predict
    pred = xgb_pipeline.predict(customer)[0]
    prob = xgb_pipeline.predict_proba(customer)[0][1]
    
    # Return result
    result = "High Risk" if pred == 1 else "Not High Risk"
    return f"{result} (Risk Probability: {prob:.2%})"

# Example usage
print(predict_risk(52, 54.20, 'Month-to-month', 'Credit', 'DSL', 'No', 'Yes', 1))
print(predict_risk(15, 35.28, 'Month-to-month', 'Debit', 'DSL', 'No', 'No', 2))
print(predict_risk(61, 80.24, 'One year', 'Cash', 'Fiber', 'Yes', 'Yes', 0))
print(predict_risk(2, 120.00, 'Month-to-month', 'Credit', 'Fiber', 'No', 'No', 5))
# Out:
# Not High Risk (Risk Probability: 11.14%)
# Not High Risk (Risk Probability: 6.71%)
# Not High Risk (Risk Probability: 4.86%)
# High Risk (Risk Probability: 98.93%)
